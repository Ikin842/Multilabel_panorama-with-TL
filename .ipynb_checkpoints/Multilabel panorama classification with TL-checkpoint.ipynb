# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import jcopdl
from torch import nn, optim
from jcopdl.callback import Callback, set_config

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else"cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Dataset & Dataloader

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from jcopdl.utils.dataloader import MultilabelDataset

# %% [markdown]
# - crop_size = 224 -> hampir semua arsitektur yg terkenal csnya = 224
#
# - transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) ini normalisasi rata rata dan standard deviasi imagenet
#
# - ingat yaa kalo kita mau pake arsitektur orang kita harus ngikutin aturan orang itu
#
#
# - problem kita kali ini adalah multilabel
#
# - ingat ingat multilabel itu bisa memprediksi dua label / lebih makanya namanya multi label, dan masing masing labelnya ada probabiltynya dan aktivasi trakhirnya menggunakan BCEloss
#
# - kalo multiclass itu hanya satu class dan ini aktivasi trakhirnya pake softmax, tapi ingat angka desimal yg terlalu kecil itu bahaya bg komputer makanya idealnya kita pake logsoftmax

# %%
bs = 64
crop_size = 224

train_transform = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.RandomResizedCrop(crop_size, scale=(0.7, 1)), # maksimum zoom 70% data
    transforms.RandomHorizontalFlip(), # panorama harusnya gamasalah kalo horizontal
    transforms.ToTensor(), # jadiin tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize(230),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


train_set = MultilabelDataset("data/train_label.csv", "data/train/", transform=train_transform)
trainloader = DataLoader(train_set, batch_size=bs, shuffle=True, num_workers=4)

test_set = MultilabelDataset("data/test_label.csv", "data/test/", transform=test_transform)
testloader = DataLoader(test_set, batch_size=bs, shuffle=True)

# %%
label2cat = train_set.classes
label2cat
# Out:
# ['desert', 'mountains', 'sea', 'sunset', 'trees']

# %% [markdown]
# # Arsitektur dan config
#
#
# ### contoh cara pakai pretrained-model
#
# mnet = mobilenet_v2(pretrained=True)
#
# - kalo pretrained = True --> dia akan download modelnya beserta weightmya, tapi kalo
# - False weightnya akan acak dan cuma arsitekturnya doang

# %%
from torchvision.models import mobilenet_v2 # arsitektur terkenal sudah disediakan disini

# %%
mnet = mobilenet_v2(pretrained=True) # load arsitektur terkenal

for param in mnet.parameters():
    param.requires_grad = False # otomatis dia gaakan ngitung gradient, kalo gadiitung otomatis weightnya beku
    
mnet.classifier = nn.Sequential(
    nn.Linear(1280, 5), # ganti sesuai dg kebutuhan kita, input sizenya sama yg beda adalah outputnya
    nn.Sigmoid()
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2da59c74915d> in <module>
# ----> 1 mnet = mobilenet_v2(pretrained=True) # load arsitektur terkenal
#       2
#       3 for param in mnet.parameters():
#       4     param.requires_grad = False # otomatis dia gaakan ngitung gradient, kalo gadiitung otomatis weightnya beku
#       5
#
# NameError: name 'mobilenet_v2' is not defined

# %%
# mnet

# %%
class CustomMobilenetV2(nn.Module):
    def __init__(self, output_size):
        super().__init__()
        self.mnet = mobilenet_v2(pretrained=True)
        self.freeze() # difreeze
        self.mnet.classifier = nn.Sequential( # tuker kepalanya
            nn.Linear(1280, output_size),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        return self.mnet(x)
    
    def freeze(self):
        for param in self.mnet.parameters():
            param.requires_grad = False
            
    def unfreeze(self): # karena kedepanya toh kita mau ngeunfreeze
        for param in self.mnet.parameters():
            param.requires_grad = True

# %%
config = set_config({
    "output_size" : len(train_set.classes),
    "batch_size" : bs,
    "crop_size" : crop_size
})

# %% [markdown]
# # Phase 1 : Adaptation (lr standard + patient kecil)

# %%
model = CustomMobilenetV2(config.output_size).to(device)
criterion = nn.BCELoss()
optimizer = optim.AdamW(model.parameters(), lr=0.001)
callback = Callback(model, config, early_stop_patience=2, outdir="model")

# %%
from tqdm.auto import tqdm


def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "test":
        model.eval()
    cost = 0
    for feature, target in tqdm(dataloader, desc=mode.title()):
        feature, target = feature.to(device), target.to(device)
        output = model(feature)
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
        cost += loss.item() * feature.shape[0]
    cost = cost / len(dataset)
    return cost

# %%
while True:
    train_cost = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)
        
    # Logging
    callback.log(train_cost, test_cost)
    
    # checkpoint
    callback.save_checkpoint()
    
    # Runtime plotting
    callback.cost_runtime_plotting()
    
    # Early stopping
    if callback.early_stopping(model, monitor="test_cost"):
        callback.plot_cost()
        break
# Out:
# ...
# Epoch     1
# Train_cost  = 0.3436 | Test_cost  = 0.3027 |
# ...
# Epoch     2
# Train_cost  = 0.3082 | Test_cost  = 0.2738 |
# ...
# Epoch     3
# Train_cost  = 0.2623 | Test_cost  = 0.2688 |
# ...
# Epoch     4
# Train_cost  = 0.2503 | Test_cost  = 0.2445 |
# ...
# Epoch     5
# Train_cost  = 0.2458 | Test_cost  = 0.2456 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.2445
# ...
# Epoch     6
# Train_cost  = 0.2370 | Test_cost  = 0.2308 |
# ...
# Epoch     7
# Train_cost  = 0.2259 | Test_cost  = 0.2223 |
# ...

# %% [markdown]
# # Phase 2 : fine-tuning (lr dikecilin, patience ditambah)

# %%
model.unfreeze()
optimizer = optim.AdamW(model.parameters(), lr=1e-5)


callback.reset_early_stop() # reset balik ke 0
callback.early_stop_patience = 5 # patiencenya jadiin 5

# %%
while True:
    train_cost = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)
        
    # Logging
    callback.log(train_cost, test_cost)
    
    # checkpoint
    callback.save_checkpoint()
    
    # Runtime plotting
    callback.cost_runtime_plotting()
    
    # Early stopping
    if callback.early_stopping(model, monitor="test_score"):
        callback.plot_cost()
        break

# %% [markdown]
# # Predict

# %%
feature, target = next(iter(testloader))
feature, target = feature.to(device), target.to(device)

with torch.no_grad():
    model.eval() # evaluasi
    output = model(feature) # feedforward
    preds = (output > 0.5).to(torch.float32) # output yg diatas 50% kita anggap prediksi kita
preds

# %% [markdown]
# # Sanity check

# %%
def convert_to_label(x):
    return (label for pred, label in zip(x, label2cat) if pred==1)

def inverse_norm(img):
    img[0, :, :] = img[0, :, :] * 0.229 + 0.485
    img[1, :, :] = img[1, :, :] * 0.224 + 0.456
    img[2, :, :] = img[2, :, :] * 0.225 + 0.406
    return img

# jangan lupa image kita diinverse
# dikali std + mean -> supaya warnanya ga aneh

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(6, 6, figsize=(24, 24))
for img, label, pred, ax in zip(feature, target, preds, axes.flatten()):
    ax.imshow(inverse_norm(img).permute(1, 2, 0).cpu())
    font = {"color" : 'r'} if (pred != label).any() else {"color" : 'g'}
    label, pred = convert_to_label(label), convert_to_label(pred)
    ax.set_title(f"Label : {label} \nPred: {pred}", fontdict=font);
    ax.axis('off');
